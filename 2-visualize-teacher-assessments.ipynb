# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
allAssessmentDF = pd.read_csv('../../astla-data/dart-preposttest/slate-data/1-teacherAssessments/all_teacherAssessments.csv', sep=',', encoding='utf-8') #.set_index('Unnamed: 0')

for var in allAssessmentDF.columns[1:]:
    allAssessmentDF[var] = allAssessmentDF[var].astype(int)
allAssessmentDF
# Out:
#                                         filename  1  2  3  4  6  7  8  9  10  \
# 0      09eae7df-db7c-491b-b7c4-a7c9fcf62f47_jong  0  1  0  1  0  1  1  1   1
# 1      09eae7df-db7c-491b-b7c4-a7c9fcf62f47_lach  1  0  1  0  1  0  0  0   0
# 2     09eae7df-db7c-491b-b7c4-a7c9fcf62f47_strik  1  1  1  1  1  1  1  1   1
# 3      09eae7df-db7c-491b-b7c4-a7c9fcf62f47_vuur  1  1  1  1  0  1  1  1   1
# 4    09eae7df-db7c-491b-b7c4-a7c9fcf62f47_specht  1  1  1  0  1  0  1  1   1
# ..                                           ... .. .. .. .. .. .. .. ..  ..
# 139  d52f2fbc-588a-4002-8c02-772dabdbfc16_vondst  1  0  1  0  1  0  0  0   0
# 140    d52f2fbc-588a-4002-8c02-772dabdbfc16_bank  1  1  1  1  1  1  1  1   1
# 141   d52f2fbc-588a-4002-8c02-772dabdbfc16_markt  1  1  1  1  1  1  1  1   1
# 142    d52f2fbc-588a-4002-8c02-772dabdbfc16_spuw  0  1  0  1  0  1  1  1   0
# 143    d52f2fbc-588a-4002-8c02-772dabdbfc16_reis  0  0  1  0  0  0  0  0   0
#
# ...

# %%
statsDF = pd.DataFrame()
statsDF['accuracy'] = allAssessmentDF.mean(axis=1)
statsDF['std'] = allAssessmentDF.std(axis=1)
statsDF['majority_vote'] = statsDF['accuracy'].apply(lambda x: x>0.5)
statsDF
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 statsDF = pd.DataFrame()
# ----> 2 statsDF['accuracy'] = allAssessmentDF.mean(axis=1)
#       3 statsDF['std'] = allAssessmentDF.std(axis=1)
#       4 statsDF['majority_vote'] = statsDF['accuracy'].apply(lambda x: x>0.5)
#
# File /vol/tensusers5/wharmsen/virenv-wav2vec2/lib/python3.10/site-packages/pandas/core/frame.py:11338, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11330 @doc(make_doc("mean", ndim=2))
#   11331 def mean(
#   11332     self,
#    (...)
#   11336     **kwargs,
#   11337 ):
# > 11338     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11339     if isinstance(result, Series):
#   11340         result = result.__finalize__(self, method="mean")
#
# ...

# %%
# Creating dataset
data = [list(statsDF['accuracy'])]

#Creating figure
fig = plt.figure()
 
# Creating plot
plt.boxplot(data)
plt.title("Accuracy scores per word")
plt.xticks([1],['Accuracy'])
plt.grid()
plt.ylabel("Accuracy")
 
# show plot
plt.show()

# %%
# statsDF['accuracy'].plot.bar(color=['yellow', 'blue', 'yellow', 'blue', 'yellow', 'blue', 'yellow', 'blue', 'yellow', 'blue',])

binnedData = pd.cut(statsDF['accuracy'], 10)
value_counts = binnedData.value_counts()
print(list(value_counts))
plt.hist(np.arange(len(list(value_counts))), height=list(value_counts), fill=False, hatch='.')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 3
#       1 # statsDF['accuracy'].plot.bar(color=['yellow', 'blue', 'yellow', 'blue', 'yellow', 'blue', 'yellow', 'blue', 'yellow', 'blue',])
# ----> 3 binnedData = pd.cut(statsDF['accuracy'], 10)
#       4 value_counts = binnedData.value_counts()
#       5 print(list(value_counts))
#
# File /vol/tensusers5/wharmsen/virenv-wav2vec2/lib/python3.10/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File /vol/tensusers5/wharmsen/virenv-wav2vec2/lib/python3.10/site-packages/pandas/core/indexes/range.py:418, in RangeIndex.get_loc(self, key)
#     416         raise KeyError(key) from err
# ...

# %%
x = statsDF['accuracy']

plt.hist(x, fill=False, hatch='')
plt.title("Histogram \n Mean Teacher Correctness Scores")
#plt.xticks([1], ['Accuracy'])
#plt.grid()
plt.ylabel("Number of words")
plt.xlabel("Mean Teacher Correctness Score")
plt.text(0,60, 'N=144')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 x = statsDF['accuracy']
#       3 plt.hist(x, fill=False, hatch='')
#       4 plt.title("Histogram \n Mean Teacher Correctness Scores")
#
# File /vol/tensusers5/wharmsen/virenv-wav2vec2/lib/python3.10/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File /vol/tensusers5/wharmsen/virenv-wav2vec2/lib/python3.10/site-packages/pandas/core/indexes/range.py:418, in RangeIndex.get_loc(self, key)
#     416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
# --> 418     raise KeyError(key)
#     419 self._check_indexing_error(key)
# ...
