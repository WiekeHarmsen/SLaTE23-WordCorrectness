# %%
import json
import glob
import pandas as pd
import reversedadapt.getAlignmentsPosttestDart as reversedadapt
import reversedadapt.textToParts as adapttexttoparts

# %%
# Read all json whisper results, and save the six relevant ones in whisperDict

jsonFiles = glob.glob('/vol/tensusers5/wharmsen/astla-data/dart-preposttest/slate-data/2-whisper-t-dis/*json')

# All SLaTE results in Dict
whisperDict = {}
for jsonFile in jsonFiles:
    with open(jsonFile, 'r') as f:
        data = json.load(f)
        fileName = jsonFile.split('/')[-1].replace('.json', '')
        whisperDict[fileName] = data

print(whisperDict.keys())
# Out:
# dict_keys(['09eae7df-db7c-491b-b7c4-a7c9fcf62f47', '74be41e8-d940-469f-8ebf-feb90250f9e8', '97549707-f715-4fe5-926c-b272b388e368', 'aa809d8a-45d1-4cc0-a2c2-b40066d2849e', 'd52f2fbc-588a-4002-8c02-772dabdbfc16', 'e5920085-8c1b-415c-b25d-24b5e5a4a2bf'])

# %%
# Create Whisper Transcription Dict

whisperTranscriptionDict = {}
for file in whisperDict.keys():
    data = whisperDict[file]
    wordDict = {}
    for segment in data['segments']:
        words = segment['words']
        for word in words:

            label = word['text']

            # If no dislefluency
            if(label != '[*]'):

                start = word['start']
                end = word['end']
                confidence = word['confidence']

                # Save word information in WordDict
                wordDict[label] = {
                    'confidence': confidence,
                    'start': start,
                    'end': end
                    }
    
    whisperTranscriptionDict[file] = wordDict

print(whisperTranscriptionDict['09eae7df-db7c-491b-b7c4-a7c9fcf62f47']['jong'])

#df = pd.DataFrame(whisperOutputList, columns=['wh_word', 'wh_acc', 'wh_start', 'wh_end'])
#df.to_csv('../../astla-data/dart-preposttest/slate-data/5-asr-analysis-results/whisper-word-assessments.csv', index=False)
# Out:
# {'confidence': 0.158, 'start': 0.94, 'end': 2.04}

# %%
# For each word in the prompt, we need to extract a correct/incorrect assessment from the Whisper ASR-output.
# We will compute this assessment in two ways:
# 1) Align prompt and output
# 2) For each prompt word, check whether it is in the output

# Prompt word is incorrectly pronounced when it is not in the ASR output, or is in the ASR-output, but has a very low confidence score

# %%
references = pd.read_csv("../../astla-data/dart-preposttest/data-in-different-formats/1-input-files/reference_wordlist.csv", sep=";")
references = references.set_index('name')
references
# Out:
#                                                       prompt
# name
# pretest0   buik web lift grapje spierkracht bal sterk mee...
# pretest1   pauw sterren gat proost lijn vlo kijken lus ba...
# pretest2   jong lach strik vuur specht keelpijn sla buite...
# posttest0  draad strik bloemen meetlat schroef waarde spr...
# posttest1  lesje kijken hagel Jaap sterk bestaat dure den...
# posttest2  vlo mooi trommel stoep nicht onze slepen raamp...

# %%
filelist = glob.glob("/vol/tensusers5/wharmsen/astla-data/dart-preposttest/slate-data/1-teacherAssessments/*.csv")

fileTestDict = {}
for file in filelist:
    parsedName = file.split('/')[-1].split('_')
    if(len(parsedName)==3):
        audio = parsedName[0]
        test = parsedName[1]
        fileTestDict[audio] = test

# %%
# Source: alignments.py
import helper_scripts.aligner as aligner

def getPrompt(audio):
    testType = fileTestDict[audio]
    return references.loc[testType, 'prompt']

def checkIfPromptInAsrTransAligned(prompt, asrTransAligned):
    return prompt in asrTransAligned


testDict = [
### false start, substitutions, substitutions
{
    'prompt': "jong lach zieke",
    'asrTrans': "jon jong lang ring"
},

### false start, 3/4 attempt correct, false start
{
    'prompt': "jong onze zieke",
    'asrTrans': "jon jong onzin onz onze z zeker"
},
### second word not pronounced
{
    'prompt': "jong onze zieke",
    'asrTrans': "jong zieke"
},
### second word not pronounced
{
    'prompt': "jong onze zieke",
    'asrTrans': "jon jong z zieke zeker"
}]

for inputPair in testDict:

    reversedadapt.getAlignmentsPromptAsrTrans(inputPair['prompt'], inputPair['asrTrans'])


        # Add begin, end and confidence scores
# Out:
#        aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# jong           jon jong                  jon jong     True
# lach               lang                      lang    False
# zieke            ri-n-g                    rin-g-    False
#         aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# jong            jon jong                  jon jong     True
# onze               onzin            onzin onz onze     True
# zieke   onz onze z zeker                  z z-eker    False
#        aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# jong               jong                      jong     True
# onze              -----                      --z-    False
# zieke             zieke                    --ieke     True
#        aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# jong               jon-                      jon-    False
# onze            jong z-              jong z zieke    False
# zieke       zieke zeker                    z-eker     True

# %%
# Initialize whisperOutputDF
whisperOutputDF = pd.DataFrame(columns=[
                               'aligned_asrTrans', 'reversed_aligned_asrTrans', 'correct', 'whisperWordIndex', 'confidence', 'begin', 'end', 'filename'])

# For each whisper output file, extract relevant information and add them to whisperOutputDF
for file in whisperTranscriptionDict.keys():
    
    print("Processing ", file, "...")

    # Get ASR transcription and prompt
    asrTranscription = " ".join(whisperTranscriptionDict[file])
    prompt = getPrompt(file)

    # Align the ASR transcription and prompt using reversed ADAPT & non-reversed ADAPT strategy with textToParts to speed up the process
    target_text_parts_list, original_text_parts_list = adapttexttoparts.textToParts(
        prompt.lower(), asrTranscription.lower())
    
    alignmentDFList= []
    for part_idx, part in enumerate(target_text_parts_list):
        alignmentPartDF = reversedadapt.getAlignmentsPromptAsrTrans(
        target_text_parts_list[part_idx].lower(), original_text_parts_list[part_idx].lower())
        alignmentDFList.append(alignmentPartDF)

    alignmentDF = pd.concat(alignmentDFList)
    # alignmentDF = reversedadapt.getAlignmentsPromptAsrTrans(
    #     prompt.lower(), asrTranscription.lower())
    alignmentDF.to_csv(
        '../../astla-data/dart-preposttest/slate-data/2-whisper-t-dis/'+file+'.csv')

    # Match info from alignmentDF with confidence scores, begin and end times

    # Try to find part of words in whisper output that match the prompt. 
    # priorities, first aligned_asrTrans, then prompt, then reversed_aligned_asrTrans
    foundIndexTermsList = []
    confidenceList = []
    startTimeList = []
    endTimeList = []
    for idx, row in alignmentDF.iterrows():
        prompt = row.name
        aligned_asrTrans = row['aligned_asrTrans'].replace('-', '')
        reversed_aligned_asrTrans = row['reversed_aligned_asrTrans'].replace(
            '-', '')
        
        indexWordAlignedAsrTrans = aligned_asrTrans if aligned_asrTrans in whisperTranscriptionDict[file].keys() else '' 
        indexWordPrompt = prompt if prompt in whisperTranscriptionDict[file].keys() else ''
        indexWordReversedAlignedAsrTrans = reversed_aligned_asrTrans if reversed_aligned_asrTrans in whisperTranscriptionDict[file].keys() else '' 
        
        if indexWordAlignedAsrTrans != '':
            foundIndexTerm = indexWordAlignedAsrTrans
            confidence = whisperTranscriptionDict[file][aligned_asrTrans]['confidence']
            startTime = whisperTranscriptionDict[file][aligned_asrTrans]['start']
            endTime = whisperTranscriptionDict[file][aligned_asrTrans]['end']
        elif indexWordPrompt != '':
            foundIndexTerm = indexWordPrompt
            confidence = whisperTranscriptionDict[file][prompt]['confidence']
            startTime = whisperTranscriptionDict[file][prompt]['start']
            endTime = whisperTranscriptionDict[file][prompt]['end']
        elif indexWordReversedAlignedAsrTrans != '':
            foundIndexTerm = indexWordReversedAlignedAsrTrans
            confidence = whisperTranscriptionDict[file][reversed_aligned_asrTrans]['confidence']
            startTime = whisperTranscriptionDict[file][reversed_aligned_asrTrans]['start']
            endTime = whisperTranscriptionDict[file][reversed_aligned_asrTrans]['end']
        else:
            foundIndexTerm = ''
            confidence = 0
            startTime = 0
            endTime = 0

        foundIndexTermsList.append(foundIndexTerm)
        confidenceList.append(confidence)
        startTimeList.append(startTime)
        endTimeList.append(endTime)

    alignmentDF['whisperWordIndex'] = foundIndexTermsList
    alignmentDF['confidence'] = confidenceList
    alignmentDF['begin'] = startTimeList
    alignmentDF['end'] = endTimeList
    alignmentDF['filename'] = [file] * len(alignmentDF)

    whisperOutputDF = pd.concat([whisperOutputDF, alignmentDF])
# Out:
# Processing  09eae7df-db7c-491b-b7c4-a7c9fcf62f47 ...
#          aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# jong                 jong                      jong     True
# lach                 lang                      lang    False
# strik               strik                     strik     True
# vuur                 vuur                      vuur     True
# specht             specht                    specht     True
# keelpijn         keelpijn                  keelpijn     True
# sla                   sla                       sla     True
# buiten             buiten                    buiten     True
# kous                 kous                      kous     True
#          aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# pink                 pink                      pink     True
# schuur             schuur                    schuur     True
# huisje             huisje                    huisje     True
# tussen             tussen                    tussen     True
# fop                   fop                       fop     True
# zwart               zwart                     zwart     True
# koen                 koen                      koen     True
# denk                 denk                      denk     True
# boomstam         boomstam                  boomstam     True
#         aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# muis                muis                      muis     True
# schrift          schrift                   schrift     True
# blauw              blauw                     blauw     True
# hond                hond                      hond     True
# zieke             ri-n-g                    rin-g-    False
# saus                saus                      saus     True
# Processing  74be41e8-d940-469f-8ebf-feb90250f9e8 ...
#         aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# pauw                pauw                      pauw     True
# sterren          sterren                   sterren     True
# gat                  gat                       gat     True
# proost            proost                    proost     True
# lijn                lijn                      lijn     True
# vlo                  vlo                       vlo     True
# kijken            kijken                    kijken     True
# lus                  lus                       lus     True
# bank                bank                      bank     True
# schoen            schoen                    schoen     True
#         aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# pad                  pad                       pad     True
# markt              markt                     markt     True
# neef                neef                      neef     True
# zoutje            zoutje                    zoutje     True
# melk                melk                      melk     True
# job                  job                       job     True
# bestaat          bestaat                   bestaat     True
# reis                reis                      reis     True
# schrik            schrik                    schrik     True
#        aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# vang               vang                      vang     True
# nu                   nu                        nu     True
# waai               waai                      waai     True
# hout               hout                      hout     True
# juicht           juicht                    juicht     True
# Processing  97549707-f715-4fe5-926c-b272b388e368 ...
#         aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# draad              d-aad                     d-aad    False
# strik              strik                     strik     True
# bloemen          bloemen                   bloemen     True
# meetlat          meetlat                   meetlat     True
# schroef          schroef                   schroef     True
# waarde            waarde                    waarde     True
# spreeuw          spreeuw                   spreeuw     True
# klets              klets                     klets     True
#             aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# genoeg                genoeg                    genoeg     True
# sproeien            sproeien                  sproeien     True
# lach                    lach                      lach     True
# spierkracht      spierkracht               spierkracht     True
# bomen                  bomen                     bomen     True
# schuur                schuur                    schuur     True
#           aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# nu                      nu                  nu sneeu     True
# panter       sneeuw panter                  w panter     True
# schrapen          schrapen                  schrapen     True
# hink                  hink                      hink     True
# waai                  waai                      waai     True
# sneeuwpop        sneeuwpop                 sneeuwpop     True
# zoutje              zoutje                    zoutje     True
#          aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# kappen             kappen                    kappen     True
# vreemdst        ---------                  ----m---    False
# melk                 melk                     --elk     True
# Processing  aa809d8a-45d1-4cc0-a2c2-b40066d2849e ...
#             aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# buik                    buik                      buik     True
# web                      web                       web     True
# lift                    lift                      lift     True
# grapje                grapje                    grapje     True
# spierkracht      spierkracht               spierkracht     True
# bal                      bal                       bal     True
# sterk                  sterk                     sterk     True
# meetlat              meetlat                   meetlat     True
#         aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# bo                    bo                        bo     True
# onze                onz-                      onze     True
# geit               --e--                      ---t    False
# toch                toch                     --och     True
# jaap                jaap                      jaap     True
# schraal          schraal             schraal graal     True
# genoeg      graal genoeg                    genoeg     True
# mug                  mug                       mug     True
# raampje          raampje                   raampje     True
#         aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# deuk                deuk                      deuk     True
# schroef          schroef                   schroef     True
# mooi                mooi                      mooi     True
# muur                muur                      muur     True
# frank              frank                     frank     True
# stoep              stoep                     stoep     True
# flits              flits                     flits     True
# Processing  d52f2fbc-588a-4002-8c02-772dabdbfc16 ...
#         aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# vlo                  flo                       flo    False
# mooi                mooi                      mooi     True
# trommel          trommel                   trommel     True
# stoep              stoep                     stoep     True
# nicht             ni--et                    nie--t    False
# onze                onze                 onze spee     True
# slepen      speen slepen                  n slepen     True
# raampje          raampje                   raampje     True
#           aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# tussen              tusse-                    tussen     True
# zanger             ---n---                    ------    False
# flits                flits                    -flits     True
# sportpark        sportpark                 sportpark     True
# deken                deken                     deken     True
# dof                    dof                       dof     True
# hond                  hond                      hond     True
# bewaar              bewaar                    bewaar     True
# nieuwtje          nieuwtje                  nieuwtje     True
#         aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# schroot          schroot                   schroot     True
# buiten            buiten                    buiten     True
# vondst            vondst                    vondst     True
# bank                bank                      bank     True
# markt              markt                     markt     True
# spuw                spuw                      spuw     True
# reis                reis                      reis     True
# Processing  e5920085-8c1b-415c-b25d-24b5e5a4a2bf ...
#         aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# lesje             leesje                    leesje    False
# kijken            kijken                    kijken     True
# hagel              hagel                     hagel     True
# jaap                jaap                      jaap     True
# sterk              sterk                     sterk     True
# bestaat          bestaat                   bestaat     True
# dure                dure                      dure     True
# denk                denk                      denk     True
# stoei              stoei                     stoei     True
#          aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# kraken             kraken                    kraken     True
# schrik             schrik                    schrik     True
# boomstam         boomstam                  boomstam     True
# warmst             warmst                    warmst     True
# jong                 jong                      jong     True
# web                   web                       web     True
# zieke               zieke                     zieke     True
# rechtsaf         rechtsaf                  rechtsaf     True
#         aligned_asrTrans reversed_aligned_asrTrans  correct
# prompt
# spa                  spa                       spa     True
# sterren          sterren                   sterren     True
# nieuw              nieuw                     nieuw     True
# juicht            juicht                    juicht     True
# vorst              vorst                     vorst     True
# stuwdam          stuwdam                   stuwdam     True
# lijn                lijn                      lijn     True

# %%
def getIndexColumn(row):
    return row['filename'] + '_' + row['prompt']

whisperOutputDF['prompt'] = whisperOutputDF.index
whisperOutputDF['index'] = whisperOutputDF.apply(getIndexColumn, axis=1)
whisperOutputDF = whisperOutputDF.set_index('index')
whisperOutputDF
# Out:
#                                              aligned_asrTrans  \
# index
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_jong                jong
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_lach                lang
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_strik              strik
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_vuur                vuur
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_specht            specht
# ...                                                       ...
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_nieuw              nieuw
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_juicht            juicht
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_vorst              vorst
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_stuwdam          stuwdam
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_lijn                lijn
#
#                                              reversed_aligned_asrTrans  \
# index
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_jong                         jong
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_lach                         lang
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_strik                       strik
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_vuur                         vuur
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_specht                     specht
# ...                                                                ...
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_nieuw                       nieuw
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_juicht                     juicht
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_vorst                       vorst
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_stuwdam                   stuwdam
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_lijn                         lijn
#
#                                              correct whisperWordIndex  \
# index
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_jong       True             jong
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_lach      False             lang
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_strik      True            strik
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_vuur       True             vuur
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_specht     True           specht
# ...                                              ...              ...
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_nieuw      True            nieuw
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_juicht     True           juicht
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_vorst      True            vorst
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_stuwdam    True          stuwdam
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_lijn       True             lijn
#
#                                              confidence  begin    end  \
# index
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_jong         0.158   0.94   2.04
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_lach         0.282   2.48   2.68
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_strik        0.463   2.72    4.8
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_vuur         0.212    4.8   5.56
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_specht       0.026   6.04   6.98
# ...                                                 ...    ...    ...
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_nieuw          0.6  18.17  18.73
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_juicht        0.23  18.73  19.43
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_vorst        0.022  19.83  20.73
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_stuwdam      0.027  21.09  22.11
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_lijn         0.589  22.11  22.87
#
#                                                                           filename  \
# index
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_jong     09eae7df-db7c-491b-b7c4-a7c9fcf62f47
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_lach     09eae7df-db7c-491b-b7c4-a7c9fcf62f47
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_strik    09eae7df-db7c-491b-b7c4-a7c9fcf62f47
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_vuur     09eae7df-db7c-491b-b7c4-a7c9fcf62f47
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_specht   09eae7df-db7c-491b-b7c4-a7c9fcf62f47
# ...                                                                            ...
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_nieuw    e5920085-8c1b-415c-b25d-24b5e5a4a2bf
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_juicht   e5920085-8c1b-415c-b25d-24b5e5a4a2bf
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_vorst    e5920085-8c1b-415c-b25d-24b5e5a4a2bf
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_stuwdam  e5920085-8c1b-415c-b25d-24b5e5a4a2bf
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_lijn     e5920085-8c1b-415c-b25d-24b5e5a4a2bf
#
#                                                prompt
# index
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_jong        jong
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_lach        lach
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_strik      strik
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_vuur        vuur
# 09eae7df-db7c-491b-b7c4-a7c9fcf62f47_specht    specht
# ...                                               ...
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_nieuw      nieuw
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_juicht    juicht
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_vorst      vorst
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_stuwdam  stuwdam
# e5920085-8c1b-415c-b25d-24b5e5a4a2bf_lijn        lijn
#
# [144 rows x 9 columns]

# %%
whisperOutputDF.to_csv('../../astla-data/dart-preposttest/slate-data/5-asr-analysis-results/whisper-word-assessments-all.csv')

# %% [markdown]
# ## Output/Conclusion
# The output of this script can be found here:
#
#     '../../astla-data/dart-preposttest/slate-data/5-asr-analysis-results/whisper-word-assessments-all.csv'

# %% [markdown]
# ## Some blocks with example code

# %%
# EXAMPLE CODE for parsing whisper dictionary

for file in whisperDict.keys():
    data = whisperDict[file]
    print(data.keys())
    # ['text', 'segments', 'language']
    print(data['segments'])
    # list of Segment (Segment[])
    print(data['segments'][0].keys())
    # ['id', 'seek', 'start', 'end', 'text', 'tokens', 'temperature', 'avg_logprob', 'compression_ratio', 'no_speech_prob', 'confidence', 'words']
    print(data['segments'][0]['words'])
    # List of words (Word[])
    print(data['segments'][0]['words'][0]['text'])
    print(data['segments'][0]['words'][0]['start'])
    print(data['segments'][0]['words'][0]['end'])
    print(data['segments'][0]['words'][0]['confidence'])
# Out:
# dict_keys(['text', 'segments', 'language'])
# [{'id': 0, 'seek': 0, 'start': 0.94, 'end': 31.13, 'text': ' jong lang strik vuur specht keelpijn sla buiten kous pink schuur huisje tussen fop zwart koen denk boomstam muis schrift', 'tokens': [50364, 49151, 70, 2265, 3575, 74, 9732, 374, 768, 4701, 803, 28591, 6041, 8039, 758, 6009, 350, 563, 7022, 956, 18470, 46526, 2884, 50119, 283, 404, 11873, 446, 8384, 268, 21285, 9351, 372, 335, 2992, 271, 956, 35742, 51863], 'temperature': 0.0, 'avg_logprob': -0.37514695888612326, 'compression_ratio': 1.263157894736842, 'no_speech_prob': 0.14187833666801453, 'confidence': 0.075, 'words': [{'text': 'jong', 'start': 0.94, 'end': 2.04, 'confidence': 0.158}, {'text': '[*]', 'start': 2.04, 'end': 2.48, 'confidence': 0}, {'text': 'lang', 'start': 2.48, 'end': 2.68, 'confidence': 0.282}, {'text': '[*]', 'start': 2.68, 'end': 2.72, 'confidence': 0}, {'text': 'strik', 'start': 2.72, 'end': 4.8, 'confidence': 0.463}, {'text': 'vuur', 'start': 4.8, 'end': 5.56, 'confidence': 0.212}, {'text': '[*]', 'start': 5.56, 'end': 6.04, 'confidence': 0}, {'text': 'specht', 'start': 6.04, 'end': 6.98, 'confidence': 0.026}, {'text': '[*]', 'start': 7.37, 'end': 7.69, 'confidence': 0}, {'text': 'keelpijn', 'start': 7.69, 'end': 8.83, 'confidence': 0.464}, {'text': 'sla', 'start': 8.83, 'end': 9.39, 'confidence': 0.0}, {'text': '[*]', 'start': 9.39, 'end': 10.23, 'confidence': 0}, {'text': 'buiten', 'start': 10.23, 'end': 11.73, 'confidence': 0.001}, {'text': 'kous', 'start': 11.73, 'end': 12.65, 'confidence': 0.128}, {'text': '[*]', 'start': 12.65, 'end': 12.69, 'confidence': 0}, {'text': 'pink', 'start': 12.69, 'end': 13.61, 'confidence': 0.335}, {'text': 'schuur', 'start': 13.61, 'end': 14.71, 'confidence': 0.679}, {'text': '[*]', 'start': 14.71, 'end': 15.85, 'confidence': 0}, {'text': 'huisje', 'start': 15.85, 'end': 17.37, 'confidence': 0.008}, {'text': '[*]', 'start': 17.37, 'end': 17.94, 'confidence': 0}, {'text': 'tussen', 'start': 18.63, 'end': 18.81, 'confidence': 0.0}, {'text': '[*]', 'start': 18.81, 'end': 19.93, 'confidence': 0}, {'text': 'fop', 'start':
# dict_keys(['id', 'seek', 'start', 'end', 'text', 'tokens', 'temperature', 'avg_logprob', 'compression_ratio', 'no_speech_prob', 'confidence', 'words'])
# [{'text': '[*]', 'start': 0.62, 'end': 1.62, 'confidence': 0}, {'text': 'Pauw', 'start': 1.62, 'end': 2.46, 'confidence': 0.535}, {'text': '[*]', 'start': 2.46, 'end': 3.42, 'confidence': 0}, {'text': 'sterren', 'start': 3.42, 'end': 4.86, 'confidence': 0.036}, {'text': '[*]', 'start': 4.86, 'end': 5.0, 'confidence': 0}, {'text': 'gat', 'start': 5.0, 'end': 5.94, 'confidence': 0.64}, {'text': '[*]', 'start': 5.94, 'end': 6.55, 'confidence': 0}, {'text': 'proost', 'start': 6.99, 'end': 8.41, 'confidence': 0.586}, {'text': '[*]', 'start': 8.41, 'end': 8.85, 'confidence': 0}, {'text': 'lijn', 'start': 8.85, 'end': 9.85, 'confidence': 0.532}, {'text': '[*]', 'start': 9.85, 'end': 10.26, 'confidence': 0}, {'text': 'vlo', 'start': 10.53, 'end': 12.11, 'confidence': 0.004}, {'text': '[*]', 'start': 12.11, 'end': 13.03, 'confidence': 0}, {'text': 'kijken', 'start': 13.03, 'end': 13.61, 'confidence': 0.044}, {'text': '[*]', 'start': 13.61, 'end': 14.97, 'confidence': 0}, {'text': 'lus', 'start': 14.97, 'end': 15.61, 'confidence': 0.661}, {'text': '[*]', 'start': 16.11, 'end': 17.59, 'confidence': 0}, {'text': 'bank', 'start': 17.59, 'end': 17.69, 'confidence': 0.325}, {'text': '[*]', 'start': 17.69, 'end': 18.55, 'confidence': 0}, {'text': 'schoen', 'start': 18.55, 'end': 19.61, 'confidence': 0.896}, {'text': '[*]', 'start': 20.21, 'end': 21.51, 'confidence': 0}, {'text': 'pad', 'start': 21.51, 'end': 21.69, 'confidence': 0.006}, {'text': '[*]', 'start': 21.69, 'end': 22.87, 'confidence': 0}, {'text': 'markt', 'start': 23.63, 'end': 24.69, 'confidence': 0.001}, {'text': '[*]', 'start': 25.89, 'end': 26.33, 'confidence': 0}, {'text': 'neef', 'start': 26.33, 'end': 26.85, 'confidence': 0.581}, {'text': '[*]', 'start': 28.27, 'end': 28.86, 'confidence': 0}, {'text': 'zoutje', 'start': 28.86, 'end': 29.78, 'confidence': 0.019}, {'text': '[*]', 'start': 30.89, 'end': 32.15, 'confidence': 0}, {'text': 'melk', 'start': 32.84, 'end': 33.54, 'confidence': 0.537}]
# [*]
# 0.62
# 1.62
# 0
# dict_keys(['text', 'segments', 'language'])
# [{'id': 0, 'seek': 0, 'start': 0.71, 'end': 28.21, 'text': ' daad strik bloemen meetlat schroef waarde spreeuw klets genoeg sproeien lach spierkracht', 'tokens': [50414, 1120, 345, 3575, 74, 1749, 14071, 1677, 14087, 956, 340, 5666, 5406, 10866, 637, 701, 36824, 9671, 1385, 1049, 78, 1146, 637, 36177, 1053, 287, 608, 637, 811, 38553, 3589, 51764], 'temperature': 0.0, 'avg_logprob': -0.2800096624037799, 'compression_ratio': 1.1733333333333333, 'no_speech_prob': 0.6504126191139221, 'confidence': 0.173, 'words': [{'text': '[*]',
.24388957977294923, 'compression_ratio': 1.1159420289855073, 'no_speech_prob': 0.9320495128631592, 'confidence': 0.0, 'words': [{'text': '[*]', 'start': 34.31, 'end': 34.69, 'confidence': 0}, {'text': 'panter', 'start': 34.69, 'end': 36.35, 'confidence': 0.0}]}, {'id': 4, 'seek': 2800, 'start': 36.35, 'end': 38.63, 'text': ' schrapen', 'tokens': [50764, 956, 4007, 268, 50864], 'temperature': 0.0, 'avg_logprob': -0.24388957977294923, 'compression_ratio': 1.1159420289855073, 'no_speech_prob': 0.9320495128631592, 'confidence': 0.013, 'words': [{'text': '[*]', 'start': 36.35, 'end': 37.27, 'confidence': 0}, {'text': 'schrapen', 'start': 37.27, 'end': 38.63, 'confidence': 0.013}]}, {'id': 5, 'seek': 2800, 'start': 40.95, 'end' ...
# dict_keys(['id', 'seek', 'start', 'end', 'text', 'tokens', 'temperature', 'avg_logprob', 'compression_ratio', 'no_speech_prob', 'confidence', 'words'])
# [{'text': '[*]', 'start': 0.71, 'end': 1.77, 'confidence': 0}, {'text': 'daad', 'start': 1.77, 'end': 2.69, 'confidence': 0.076}, {'text': '[*]', 'start': 2.69, 'end': 3.19, 'confidence': 0}, {'text': 'strik', 'start': 3.19, 'end': 4.59, 'confidence': 0.067}, {'text': '[*]', 'start': 4.59, 'end': 5.03, 'confidence': 0}, {'text': 'bloemen', 'start': 5.03, 'end': 6.97, 'confidence': 0.64}, {'text': '[*]', 'start': 6.97, 'end': 7.77, 'confidence': 0}, {'text': 'meetlat', 'start': 7.77, 'end': 10.05, 'confidence': 0.102}, {'text': '[*]', 'start': 10.05, 'end': 11.07, 'confidence': 0}, {'text': 'schroef', 'start': 11.07, 'end': 12.37, 'confidence': 0.528}, {'text': '[*]', 'start': 12.37, 'end': 12.69, 'confidence': 0}, {'text': 'waarde', 'start': 12.69, 'end': 14.15, 'confidence': 0.022}, {'text': '[*]', 'start': 14.15, 'end': 14.63, 'confidence': 0}, {'text': 'spreeuw', 'start': 14.63, 'end': 16.75, 'confidence': 0.16}, {'text': '[*]', 'start': 16.75, 'end': 17.99, 'confidence': 0}, {'text': 'klets', 'start': 17.99, 'end': 19.11, 'confidence': 0.001}, {'text': '[*]', 'start': 19.11, 'end': 20.35, 'confidence': 0}, {'text': 'genoeg', 'start': 20.35, 'end': 22.27, 'confidence': 0.341}, {'text': '[*]', 'start': 22.27, 'end': 22.75, 'confidence': 0}, {'text': 'sproeien', 'start': 22.75, 'end': 24.39, 'confidence': 0.547}, {'text': '[*]', 'start': 24.39, 'end': 24.45, 'confidence': 0}, {'text': 'lach', 'start': 24.45, 'end': 25.45, 'confidence': 0.431}, {'text': 'spierkracht', 'start': 25.45, 'end': 28.21, 'confidence': 0.738}]
# [*]
# 0.71
# 1.77
# 0
# dict_keys(['text', 'segments', 'language'])
# [*]
# 1.39
# 1.83
# 0
# dict_keys(['text', 'segments', 'language'])
# [{'id': 0, 'seek': 0, 'start': 0.0, 'end': 30.14, 'text': ' flo mooi trommel stoep niet onze speen slepen raampje tussen', 'tokens': [50364, 2591, 275, 1986, 72, 504, 1204, 338, 22784, 595, 3867, 302, 29460, 768, 268, 2426, 5200, 3342, 1215, 2884, 50119, 710, 3176, 51814], 'temperature': 0.0, 'avg_logprob': -0.7116177368164063, 'compression_ratio': 1.0634920634920635, 'no_speech_prob': 0.257934033870697, 'confidence': 0.075, 'words': [{'text': '[*]', 'start': 0.0, 'end': 1.2, 'confidence': 0}, {'text': 'flo', 'start': 1.2, 'end': 1.82, 'confidence': 0.043}, {'text': '[*]', 'start': 1.82, 'end': 3.18, 'confidence': 0}, {'text': 'mooi', 'start': 3.18, 'end': 4.34, 'confidence': 0.114}, {'text': '[*]', 'start': 4.34, 'end': 4.56, 'confidence': 0}, {'text': 'trommel', 'start': 4.56, 'end': 7.16, 'confidence': 0.203}, {'text': '[*]', 'start': 7.16, 'end': 7.89, 'confidence': 0}, {'text': 'stoep', 'start': 8.24, 'end': 9.12, 'confidence': 0.563}, {'text': '[*]', 'start': 9.12, 'end': 9.52, 'confidence': 0}, {'text': 'niet', 'start': 9.52, 'end': 10.26, 'confidence': 0.065}, {'text': '[*]', 'start': 10.26, 'end': 12.0, 'confidence': 0}, {'text': 'onze', 'start': 12.0, 'end': 12.3, 'confidence': 0.027}, {'text': '[*]', 'start': 13.45, 'end': 18.48, 'confidence': 0}, {'text': 'speen', 'start': 19.11, 'end': 22.21, 'confidence': 0.136}, {'text': '[*]', 'start': 22.21, 'end': 23.95, 'confidence': 0}, {'text': 'slepen', 'start': 24.48, 'end': 26.04, 'confidence': 0.016}, {'text': '[*]', 'start': 26.04, 'end': 27.56, 'confidence': 0}, {'text': 'raampje', 'start': 27.56, 'end': 29.08, 'confidence': 0.43}, {'text': 'tussen', 'start': 29.08, 'end': 30.14, 'confidence': 0.01}]}, {'id': 1, 'seek': 3000, 'start': 53.03, 'end': 58.22, 'text': ' flits sportpark deken', 'tokens': [50364, 932, 1208, 7282, 31239, 368, 2653, 360, 69, 276, 684, 312, 4151, 289, 26829, 86, 83, 2884, 956, 44147, 51514], 'temperature': 0.0, 'avg_logprob': -0.35233431277067767, 'compression_ratio': 0.9473684210526315, 'no_speech_prob': 0.9167375564575195, 'confidence': 0.006, 'words': [{'text': 'flits', 'start': 53.03, 'end': 53.05, 'confidence': 0.017}, {'text': 'sportpark', 'start': 53.05, 'end': 54.35, 'confidence': 0.0}, {'text': '[*]', 'start': 55.48, 'end': 57.78, 'confidence': 0}, {'text': 'deken', 'start': 57.78, 'end': 58.22, 'confidence': 0.005}]}, {'id': 2, 'seek': 5300, 'start': 58.24, 'end': 81.28, 'text': ' deken dof hond bewaar nieuwtje schroot buiten vondst', 'tokens': [50414, 368, 2653, 360, 69, 276, 684, 312, 4151, 289, 26829, 86, 83, 2884, 956, 44147, 758, 6009, 371, 684, 372, 51514], 'temperature': 0.0, 'avg_logprob': -0.31175116697947186, 'compression_ratio': 0.9454545454545454, 'no_speech_prob': 0.9587650895118713, 'confidence': 0.225, 'words': [{'text': 'deken', 'start': 58.24, 'end': 59.96, 'confidence': 0.044}, {'text': '[*]', 'start': 59.96, 'end': 60.64, 'confidence': 0}, {'text': 'dof', 'start': 60.64, 'end': 61.34, 'confidence': 0.181}, {'text': '[*]', 'start': 61.34, 'end': 61.62, 'confidence': 0}, {'text': 'hond', 'start': 61.62, 'end': 62.32, 'confidence': 0.715}, {'text': '[*]', 'start': 62.32, 'end': 63.25, 'confidence': 0}, {'text': 'bewaar', 'start': 63.79, 'end': 65.15, 'confidence': 0.555}, {'text': '[*]', 'start': 65.15, 'end': 66.11, 'confidence': 0}, {'text': 'nieuwtje', 'start': 66.11, 'end': 67.47, 'confidence': 0.605}, {'text': '[*]', 'start': 67.47, 'end': 70.85, 'confidence': 0}, {'text': 'schroot', 'start': 70.85, 'end': 72.15, 'confidence': 0.141}, {'text': '[*]', 'start': 72.15, 'end': 73.04, 'confidence': 0}, {'text': 'buiten', 'start': 73.47, 'end': 74.77, 'confidence': 0.695}, {'text': '[*]', 'start': 76.62, 'end': 78.32, 'confidence': 0}, {'text': 'vondst', 'start': 78.32, 'end': 81.28, 'confidence': 0.025}]}, {'id': 3, 'seek': 7600, 'start': 81.28, 'end': 87.94, 'text': ' bank markt spuw reis', 'tokens': [50364, 3765, 1491, 83, 637, 36824, 319, 271, 50664], 'temperature': 0.0, 'avg_logprob': -0.4433137893676758, 'compres ...
# dict_keys(['id', 'seek', 'start', 'end', 'text', 'tokens', 'temperature', 'avg_logprob', 'compression_ratio', 'no_speech_prob', 'confidence', 'words'])
# [{'text': '[*]', 'start': 0.0, 'end': 1.2, 'confidence': 0}, {'text': 'flo', 'start': 1.2, 'end': 1.82, 'confidence': 0.043}, {'text': '[*]', 'start': 1.82, 'end': 3.18, 'confidence': 0}, {'text': 'mooi', 'start': 3.18, 'end': 4.34, 'confidence': 0.114}, {'text': '[*]', 'start': 4.34, 'end': 4.56, 'confidence': 0}, {'text': 'trommel', 'start': 4.56, 'end': 7.16, 'confidence': 0.203}, {'text': '[*]', 'start': 7.16, 'end': 7.89, 'confidence': 0}, {'text': 'stoep', 'start': 8.24, 'end': 9.12, 'confidence': 0.563}, {'text': '[*]', 'start': 9.12, 'end': 9.52, 'confidence': 0}, {'text': 'niet', 'start': 9.52, 'end': 10.26, 'confidence': 0.065}, {'text': '[*]', 'start': 10.26, 'end': 12.0, 'confidence': 0}, {'text': 'onze', 'start': 12.0, 'end': 12.3, 'confidence': 0.027}, {'text': '[*]', 'start': 13.45, 'end': 18.48, 'confidence': 0}, {'text': 'speen', 'start': 19.11, 'end': 22.21, 'confidence': 0.136}, {'text': '[*]', 'start': 22.21, 'end': 23.95, 'confidence': 0}, {'text': 'slepen', 'start': 24.48, 'end': 26.04, 'confidence': 0.016}, {'text': '[*]', 'start': 26.04, 'end': 27.56, 'confidence': 0}, {'text': 'raampje', 'start': 27.56, 'end': 29.08, 'confidence': 0.43}, {'text': 'tussen', 'start': 29.08, 'end': 30.14, 'confidence': 0.01}]
